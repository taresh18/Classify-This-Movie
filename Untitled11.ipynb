# %% [markdown]
# <a href="https://colab.research.google.com/github/taresh18/Classify-This-Movie/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install kaggle

# %%
# !pip install timm
import timm

# %%
! pip install sklearn

# %%
import os
os.environ['KAGGLE_USERNAME'] = "tareshrajput" # username from the json file
os.environ['KAGGLE_KEY'] = "489d6ed77e0b2b01cf027c2f93bd687c" # key from the json file
# !kaggle datasets download -d sshukla21/clabscvcomp # api copied from kaggle
# !unzip -qq clabscvcomp.zip
# !rm -r clabscvcomp.zip
# Out:
# ...
# 100% 11.0G/11.1G [04:24<00:00, 42.0MB/s]
# 100% 11.1G/11.1G [04:24<00:00, 44.8MB/s]

# %%
from fastai import *
from fastai.vision import *
from sklearn.metrics import f1_score

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
seed_everything(43)

# %%
train = pd.read_csv('data/train.csv')
test_df = pd.read_csv('data/sample_submission.csv')

train.head() ## Shows the first five rows of data frame
# Out:
#        id       genres
# 0   71139       Comedy
# 1   73330       Comedy
# 2   53693  Documentary
# 3  121140       Horror
# 4   45090    Adventure

# %%
sorted(train.genres.unique()) ## Shows all classes in the dataframe
# Out:
# ['Action',
#  'Adventure',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Horror',
#  'Romance',
#  'Sci-Fi',
#  'Thriller']

# %%
train.genres.value_counts(normalize=True) ## Distribution of dataset
# Out:
# Comedy         0.184648
# Documentary    0.171221
# Drama          0.139154
# Horror         0.132541
# Thriller       0.097067
# Action         0.092257
# Romance        0.086379
# Crime          0.035473
# Adventure      0.034672
# Sci-Fi         0.026588
# Name: genres, dtype: float64

# %%
sz=512
bs=16
tfms = get_transforms(do_flip=True,flip_vert=False, max_rotate=60, max_zoom=2.5, max_lighting=0.7)
data = (ImageList.from_df(df=train,path='data/train_data/',cols='id',suffix = '.jpg') 
    .split_by_rand_pct(valid_pct=0.2)
    .label_from_df(cols='genres')
    .transform(tfms,size=sz, padding_mode='border', resize_method=ResizeMethod.SQUISH)
    .databunch(bs=bs,num_workers=4) 
    .normalize(imagenet_stats))

# %%
test_data = ImageList.from_df(test_df, path='data/test_data/', cols='id', suffix = '.jpg')
data.add_test(test_data)

# %%
data.show_batch(3)

# %%
def F1(y_pred, y):
    y_pred = y_pred.softmax(dim=1) 
    y_pred = y_pred.argmax(dim=1)
    return torch.tensor(f1_score(y.cpu(), y_pred.cpu(), labels=list(range(10)), average='weighted'),device='cuda:0')

# %%
learn = cnn_learner(
                    data, ## DataBunch
                    timm.models.resnext101_32x4d,
                    metrics=[F1, accuracy], ## Matrices
                    callback_fns=ShowGraph ## Allows us to visualize training
).mixup()
# Out:
# WARNING:root:Pretrained model URL is invalid, using random initialization.

# %%
learn.freeze() 
learn.fit_one_cycle(1)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>F1</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
# ...

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot(suggestion=True)

# %%
learn.fit_one_cycle(1, max_lr=slice(1e-4, 1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>F1</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.302818</td>
#       <td>2.218676</td>
#       <td>0.184876</td>
#       <td>0.190444</td>
#       <td>21:13</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)

# %%
preds = learn.get_preds(ds_type=DatasetType.Test) ## get prediction in test data
preds = np.argmax(preds[0].numpy(),axis = 1)
categories = sorted(train.genres.unique().astype('str'))
final_preds = []
for idx in preds:
    final_preds.append(categories[idx])
final_submit = pd.read_csv('../input/clabscvcomp/data/sample_submission.csv')
final_submit.genres = final_preds
final_submit.head()
final_submit.to_csv('submission.csv',index = False)
